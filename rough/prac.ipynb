# %%
import numpy as np

s = "0.0125 0.051  0.0062 0.0336 0.0047 0.0298 0.0154"
values = [float(v) for v in s.split()]
print(f"{np.mean(values).item():.3f}")
# Out:
# 0.022

# %%
s = "0.0097 0.0199 0.0062 0.0187 0.0113 0.0259 0.0118"
values = [float(v) for v in s.split()]
print(f"{np.mean(values).item():.3f}")
# Out:
# 0.015

# %%
213 // 3
# Out:
# 71

# %%
s = "0.1378 0.1674 0.0257 0.1113 0.0495 0.1377 0.1662"
values = [float(v) for v in s.split()]
print(f"{np.mean(values).item():.3f}")
# Out:
# 0.114
